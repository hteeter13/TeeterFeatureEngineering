# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numerical = pd.read_csv('numerical2.csv')

# %%
numerical
# Out:
#        ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  MALEMILI  \
# 0         8901      0  3712  60.000000     5.0      NaN    0         0
# 1         9401      1  5202  46.000000     6.0      9.0   16         0
# 2         9001      1     0  61.611649     3.0      1.0    2         0
# 3         8701      0  2801  70.000000     1.0      4.0    2         0
# 4         8601      0  2001  78.000000     3.0      2.0   60         1
# ...        ...    ...   ...        ...     ...      ...  ...       ...
# 95407     9601      1     0  61.611649     5.0      NaN    0        14
# 95408     9601      1  5001  48.000000     7.0      9.0    1         0
# 95409     9501      1  3801  60.000000     5.0      NaN    0         0
# 95410     8601      0  4005  58.000000     7.0      NaN    0         0
# 95411     8801      2  1801  80.000000     5.0      8.0    3         1
#
#        MALEVET  VIETVETS  ...  LASTGIFT  LASTDATE  FISTDATE  NEXTDATE  \
# ...

# %%
numerical['WEALTH1'].value_counts()
# Out:
# 9.0    7585
# 8.0    6793
# 7.0    6198
# 6.0    5825
# 5.0    5280
# 4.0    4810
# 3.0    4237
# 2.0    4085
# 1.0    3454
# 0.0    2413
# Name: WEALTH1, dtype: int64

# %%
numerical['MSA'].value_counts()
# Out:
# 0.0       21333
# 4480.0     4606
# 1600.0     4059
# 2160.0     2586
# 520.0      1685
#           ...
# 9140.0        1
# 3200.0        1
# 9280.0        1
# 743.0         1
# 8480.0        1
# Name: MSA, Length: 298, dtype: int64

# %%
numerical['ADI'].value_counts()
# Out:
# 13.0     7296
# 51.0     4622
# 65.0     3765
# 57.0     2836
# 105.0    2617
#          ...
# 651.0       1
# 103.0       1
# 601.0       1
# 161.0       1
# 147.0       1
# Name: ADI, Length: 204, dtype: int64

# %%
numerical['DMA'].value_counts()
# Out:
# 803.0    7296
# 602.0    4632
# 807.0    3765
# 505.0    2839
# 819.0    2588
#          ...
# 569.0       1
# 554.0       1
# 584.0       1
# 552.0       1
# 516.0       1
# Name: DMA, Length: 206, dtype: int64

# %%
numerical['NEXTDATE'].value_counts()
# Out:
# 9504.0    2253
# 9412.0    1970
# 8703.0    1959
# 9512.0    1870
# 8612.0    1688
#           ...
# 7711.0       1
# 8407.0       1
# 7211.0       1
# 7810.0       1
# 8412.0       1
# Name: NEXTDATE, Length: 188, dtype: int64

# %%
sns.distplot(numerical['WEALTH1'])
plt.show()
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_15872\1353491511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['WEALTH1'])

# %%
numerical['WEALTH1'] = numerical["WEALTH1"].fillna(np.mean(numerical['WEALTH1']))

# %%
sns.distplot(numerical['WEALTH1'])
plt.show()
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_15872\1353491511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['WEALTH1'])

# %%
numerical['MSA'] = numerical['MSA'].fillna(0.0)

# %%
sns.distplot(numerical['ADI'])
plt.show()
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_15872\763747731.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['ADI'])

# %%
numerical['ADI'] = numerical["ADI"].fillna(np.mean(numerical['ADI']))

# %%
numerical['DMA'] = numerical["DMA"].fillna(np.mean(numerical['DMA']))

# %%
numerical['NEXTDATE'] = numerical["NEXTDATE"].fillna(np.mean(numerical['NEXTDATE']))

# %%
numerical
# Out:
#        ODATEDW  TCODE   DOB        AGE  INCOME   WEALTH1  HIT  MALEMILI  \
# 0         8901      0  3712  60.000000     5.0  5.345699    0         0
# 1         9401      1  5202  46.000000     6.0  9.000000   16         0
# 2         9001      1     0  61.611649     3.0  1.000000    2         0
# 3         8701      0  2801  70.000000     1.0  4.000000    2         0
# 4         8601      0  2001  78.000000     3.0  2.000000   60         1
# ...        ...    ...   ...        ...     ...       ...  ...       ...
# 95407     9601      1     0  61.611649     5.0  5.345699    0        14
# 95408     9601      1  5001  48.000000     7.0  9.000000    1         0
# 95409     9501      1  3801  60.000000     5.0  5.345699    0         0
# 95410     8601      0  4005  58.000000     7.0  5.345699    0         0
# 95411     8801      2  1801  80.000000     5.0  8.000000    3         1
#
#        MALEVET  VIETVETS  ...  LASTGIFT  LASTDATE  FISTDATE     NEXTDATE  \
# ...

# %%
numerical.to_csv('numerical2.csv')

# %%
# numerical = pd.DataFrame(numerical.isna().sum()).reset_index()
# numerical.columns = ['column_name', 'nulls']
# numerical[numerical['nulls']>0]
